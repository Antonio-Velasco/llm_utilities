# %%
from langchain import OpenAI, PromptTemplate, LLMChain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains.summarize import load_summarize_chain
from langchain.chains.combine_documents.map_reduce import MapReduceDocumentsChain, Document
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
import itertools as it
from langchain.callbacks import get_openai_callback
import json
import openai
import os

with open('../settings.json') as f:
    data = json.load(f)

# This example also requires an OpenAI API key
os.environ['OPENAI_API_KEY'] = data['OPENAI_API_KEY']
openai.api_key = os.environ['OPENAI_API_KEY']

# %%
import pdfplumber

path = "../data/206_12a-3 (SW Clair F1) Geological EOWR_Signed.pdf"

text = ""
with pdfplumber.open(path) as pdf:
    for page in pdf.pages:
        text += page.extract_text()

# %%
map_prompt = """
Write a concise summary of the following:
"{text}"
CONCISE SUMMARY:
"""
map_prompt_template = PromptTemplate(template=map_prompt, input_variables=["text"])


reduce_prompt = """
Write a concise summary of the following text delimited by triple backquotes.
Return your response in bullet points which covers the key points of the text.
```{text}```
BULLET POINT SUMMARY:
"""
reduce_prompt_template = PromptTemplate(template=reduce_prompt, input_variables=["text"])


def summarization_chain(verbose=False):
    llm = OpenAI(temperature=0, max_tokens=512)

    map_chain = LLMChain(llm=llm, prompt=map_prompt_template, verbose=verbose)
    reduce_chain = LLMChain(llm=llm, prompt=reduce_prompt_template, verbose=verbose)

    combine_document_chain = StuffDocumentsChain(
        llm_chain=reduce_chain,
        document_variable_name="text",
        verbose=verbose,
    )

    mapreduce_chain = MapReduceDocumentsChain(
        llm_chain=map_chain,
        combine_document_chain=combine_document_chain,
        document_variable_name=combine_document_chain.document_variable_name,
        verbose=verbose
    )

    return mapreduce_chain


def split_text(text, separators=["\n\n", "\n", " "], chunk_size=3000, chunk_overlap=500):
    text_splitter = RecursiveCharacterTextSplitter(separators=separators + [""], chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    docs = text_splitter.create_documents([text])
    return docs


def split_in_chuncks(docs, number_of_chunks):

    chunk_size = (len(docs) // number_of_chunks)

    groups = [[group for _, group in enumerated_group] for _, enumerated_group in it.groupby(enumerate(docs), key=lambda e: e[0] // chunk_size)]
    return groups


def summarize_text(text, number_of_chunks, include_costs=False):
    with get_openai_callback() as cb:
        chain = summarization_chain()
        docs = split_text(text)
        groups = split_in_chuncks(docs, number_of_chunks)
        summaries = [chain.run(group) for group in groups]
        joined_summary = "\n\n".join(summaries)

        if include_costs:
            return joined_summary, cb
        return joined_summary

# %%
print(summarize_text(text, 10))
# Out:
# - Report provides a summary of the results of the South West Clair 206/12a-3 well, including operational summaries, petrophysical summaries, and stratigraphic breakdowns
# - Outlines data acquisition and interpretation of hydrocarbon shows from the 206/12a-3 wellsite
# - Includes rationale for formation top picks, seismic well tie, shallow hazards summary, wellsite biostratigraphy, heavy minerals, LWD summary, wireline logging summary, formation pressure and fluid sampling summary, conventional coring summary, core plugging summary, sidewall coring summary, geochemical summary, cuttings, mud and gas sample summary, oil shows, gas shows, and gas data interpretation
# - Includes sections on gas shows, gas data interpretation, pore and fracture pressure evaluation, operational decisions, faults and fractures, and operational learnings
# - Provides figures such as a depth structure map, time vs operational depth plot, reservoir properties CPI summary, MDT formation pressure points, drilled vs prognosed stratigraphy, seismic tie, shallow section observations, biostratigraphy, heavy mineral stratigraphic breakdown, formation pressure summary plot, normalised gas plot, post well PPFG plot, and LOT and FIT plots
# - Designed to appraise the West of Horst segment of the Clair Field by drilling into the basement to allow full log coverage of the Lower Clair Group (LCG) and lowermost Cretaceous reservoir targets
#
# - Well 206/12a-3 was drilled to appraise the West of Horst segment and provide velocity data for depth control
# - Spudded from a new surface location on the 9th June 2011
# - 42”x36”x30” section was drilled and 30” conductor run without significant issue
# - Two wireline logging runs were performed and the Top Santonian was identified at 2066m MDBRT (-1775.7m TVDSS)
# - Five 54m cores were cut between 2265-2467m MDBRT and seven wireline logging runs were performed
# - Objectives of the project were to acquire a series of MDT pressures and fluid samples, keep the well design consistent with mean cost of D&C and drilling performance targets, and plan for development costs in the range of $9-14/bbl
# - Drilled in 71.6 days, 38.1 days ahead of schedule, with only 15% NPT
# - BP Subsurface Team and Wells Team composed of Alistair Robertshaw, Kevin Bleasdale, Colin MacPherson, David Walshaw, Simon Whiteman, Tim Hull-Bailey, Dave Saucier, Jack Willis, Martin Ellis, Andy Morton, Mike Ayress, Dave Marshall, Sara Newns, Valerie Goggin, Tim Nash, Karen Martin, Kay Witt, Dann Halverson, Gwydion Williams, Steve Thompson, Dave Barr, Neal Blackburn, Chris Mair, Mehdi Yusifov, Mark Harrison, Robert Paterson, René Sigaard Pedersen, Adebola Ogunremi, Richard Gall, David Gilchrist, Justus Brokking, and Paul Strachan.
#
# - This report covers the drilling of a well with sections of 42x36x30", 26", 17-1/2", 12-1/4", and 8-1/2" in diameter
# - Issues such as boulders causing the mud motor to stall out, and a conductor hung up 3m from the bottom were encountered
# - Excessive flow rates and unconsolidated formation prevented the desired build
# - Damage to the monkey board and racking arm was experienced
# - A MagTrak tool failure due to a date format issue was experienced
# - The well was subject to weak bedding plane instability and required a MW OBM to control borehole instability
# - Poor drilling practices may result in washed-out hole, instability, ledges and poor hole cleaning
# - Polygonal faulting at the Maastrichtian boundary may be a cause of instability and difficult drilling conditions
#
# - The Clair Group allowed TD to be picked above the Basement Depth Penetrating reservoir, with directional work completed before reaching the coring point.
# - Magnets were run in NMR and MagTrak tools, and trajectory modifications were made to accommodate for coring requirements.
# - Archie's equation was used to calculate water saturation, and a reservoir properties summary table and CPI summary were tabulated.
# - This report provides a geological end of well report for the 206/12a-3 well, with picks including the Stronsay Group, Balder Formation, Base Tertiary Unconformity, Late Maastrictian Sands, Early Maastrichtian, Campanian, Santonian, 'Lower Cretaceous' Sands, Base Cretaceous Unconformity, Upper Clair Group Unit VI, Lower Clair Group Unit V, Lower Clair Group Unit IV, Lower Clair Group Unit III, Lower Clair Group Unit II/I, and Basement.
#
# - Report details stratigraphy from unconformity at -1076.9 to base Cretaceous at -2567.2
# - Gas levels increased over basal 40m of Balder Formation
# - Micropalaeontology used to confirm Late Maastrictian sands, Early Maastrictian, Campanian, Santonian, 'Lower Cretaceous' sands, Upper Clair Group Unit VI, Lower Clair Group Unit V, Lower Clair Group Unit IV, Lower Clair Group Unit III, Lower Clair Group Unit I/II, and Rona Formation
# - Top of package is Early Coniacian (Late Cretaceous) and evidence of probable Jurassic age at base
# - Report discusses pre-drill correlation of K80.2 Sequence Top in Wells 206/12a-3 & 206/12-2
# - No sonar contacts (boulders) found within 10m radius of spud location, but four stall-outs and slow drilling caused by boulders in subsurface
# - Micropaleontology conducted from 540m MDBRT to 2383m MDBRT to identify Clair Group
# - Formation picks confirmed by biostrat, with exception of Top Santonian (K76)
# - High ROP limited to average of 2200mm/hr, with instantaneous peaks of up to 110000mm/hr
# - Gamma Ray indicated thin detector bed at various depths
# - Alternation from rotary drilling to sliding at various depths
# - Pump 11 failure at 447711mm MDD
# - Increased weight on bit from 448899-550055mm MDD may indicate mudstone presence
#
# - Micropaleontology was used to confirm formation picks from 540m MDBRT until the Clair Group was identified at 2383m MDBRT.
# - Top Santonian formation top was picked at 2066m MDBRT, based on GR and Biostrat.
# - Onshore analysis of core is ongoing to identify the “Indeterminate” section between the base Cretaceous and Clair Group.
# - Various programs and techniques used for cutting, core, and other analysis of various materials.
# - Heavy mineral analysis was carried out from 2292m to the total depth of the well.
# - Stratigraphy identified as Lower Cretaceous, Lower Clair Group, Unit VIa, Lower Clair Group, Unit V, and Lower Clair Group, Unit IV.
# - Seven runs were completed between 25-Jun-2011 and 01-Aug-2011, using various tools.
# - Minor pack-off and MagTrak failure occurred at 2197m, and a Shuttle 3 failure occurred at 967m.
#
# - Report covers tests and fluid samples taken from a well
# - Two PBU tests conducted using large diameter probe and Quicksilver probe for sampling
# - Nitrogen compensation failure identified on two sample chambers during surface transfer
# - Rig Source VSP and PAM monitoring for marine mammals used
# - PAM hydrophone lost due to becoming entangled in the rig anchor chain
# - Gyrodata and CCL tools run on Schlumberger wireline, MDT pressures taken on the way into the hole
# - Summary table and data tables of pretest results included
# - Data provided for large diameter BQP2 and MPMP-AD(MRPQ) QDPRESS_PQ1
#
# - Report provides data on geological end of well, including measurements of depth, formation temperature, pretest pressure, hydrostatic pressure, packer/probe gauge type, pretest status, flowrate, volume, and pressure
# - Data organized into categories based on type of test (High, Medium, Low, or Tight)
# - Summary of fluid samples, formation pressure summary plot, and conventional coring summary from successful coring programme
# - Details successful coring program of SW Clair 206/12a-3 well, which met all objectives and delivered 100% recovery
# - Core depth shift table, core plugging summary, sidewall coring summary, and geochemical summary covered
# - Logging programme included rotary sidewall coring run and intensive geochemical analysis programme
# - Various sample types collected and analysed for quantity and geochemical character of entrained oil, composition and isotope ratio values, and full geochemical character
# - Data showed Cretaceous oils were physically and geochemically different, SW Clair and Clair main field oils were similar but not in communication, oil column was heterogeneous, and pressure gradient data indicated FWL was located at ±2135mTVDSS
#
# - Report details collection of samples from SW Clair 206/12a-3 well, including mud, gas, and mud samples
# - Pressure gradient data indicates FWL at ±2135mTVDSS and ODT/OWC between 2112m and 2122m TVDSS
# - Gas peaks of 0.25-0.5% seen in cored oil bearing reservoir sections in Lower Cretaceous and Lower Clair Group
# - Pore and fracture pressure evaluation showed reservoir pressures and LOT pressures close to prediction
# - Formation Integrity Test conducted on July 4th and 12th, 2011, with pressures of 360psi and 965psi respectively
#
# - A Formation Integrity Test (FIT) was conducted at the 9-5/8” shoe at 1816m TVD to a pressure of 965psi, 1.694sg EMW.
# - The 20" casing point was picked 15m into Westray Group mudstones, and the 13-3/8" casing point was picked from real-time LWD-GR at 1128.9m MDBRT.
# - The 9-5/8" casing point was picked based on wellsite micropalaeontology and log responses.
# - Magnetic MWD directional tools were used to survey the well bore, and a c.4° azimuthal difference between the magnetic and gyro surveys was observed.
# - Two dominant fracture sets were identified in the image logs, NNE-SSW and E-W striking, with a subordinate NW-SE set in the Lower Cretaceous claystone intervals.
# - In the Lower Clair Group, two fracture sets were identified, WNW-ESE and NE-SW, with most fractures being mineralised.
# - Structural dip in the Lower Cretaceous was 70o SE, while the Clair Group units dip SE and ESE.
#
# - Outlines operational learnings from SW Clair 206/12a-3 well drilling operation
# - Highlights importance of slow drilling and torque spikes in 42” section, need to involve onshore subsurface team, and need to fully adopt geological and stratigraphic prognosis
# - Suggests experienced and independent coring supervisors, check core depths against pipe tally, use H S specific detectors, include rabbiting of empty core inner tubes in standard procedures, eliminate man-riding, use tag lines when lowering core cradle, share deck layout plan, gain clarity on distance between cores, ensure core saw can cut all potential types of rock, include core photography in core processing contract, and consider mobilising soft sediment core processing options
# - Suggests sending Schlumberger personnel to the rig a minimum of 48hrs before the planned start of the job, having instructions for breaking weak points, checking lifting equipment, ensuring air pressure is adequate, using a backup processor, and considering real-time data transmission
# - Differential pressure with the sample line risked mud filtrate sample contamination, so extra high pressure and high pressure displacement units were used
# - Risk assessment based on premise that shear rams would not cut cable, 12.5T compensating line considered to prevent shear link bending, newly installed wireline unit inadequately tested prior to operation
# - HTCS compression and tension sub inaccurate when rigged vertically, Oilphase SPMC failed to fire when taking sample, shuttle 3 Z axis reading incorrectly, and PAM hydrophone cable entangled with rig cables
#
# - Comprehensive overview of geological end of well 206/12a-3 in Clair Field, West of Shetland
# - Includes formation evaluation, drilling evaluation, pressure evaluation, gas ratio log, SPMC failure report, compositional analysis, H2S coupon results, MDT contamination estimation, quality control reports, determination of ionic composition of core waters, fracture characterisation report, definitive survey report, heavy mineral stratigraphy, biostratigraphical re-evaluation, core descriptions, MDT interpretation report, sonic scanner advisor report, Q-borehole survey report, and marine mammal observer's report
# - Interpretation of Sonic Scanner Advisor Report, Q-Borehole Survey Report, Marine Mammal Observer’s Report, Structural summary plot, Sedimentological summary plot, Geochemistry Data Interpretation Final Final Summary Conclusions, Wireline Logging QC Report, Wireline Logging Report, Definitive Survey Report, Investigation into Azimuth Mismatch, and Geological End of Well Report with Appendices 1 and 2
